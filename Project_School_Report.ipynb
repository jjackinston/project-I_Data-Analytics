# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ###Reading my csv Data

# %%
missing_values = ['n/a','na','NaN','--']

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', na_values=missing_values)

# %%
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %% [markdown]
# ###Getting info of my data

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
df.tail()
# Out:
#        School DBN           School Name School Level  \
# 212326     84X717  Icahn Charter School          K-8
# 212327     84X717  Icahn Charter School          K-8
# 212328     84X717  Icahn Charter School          K-8
# 212329     84X717  Icahn Charter School          K-8
# 212330     84X717  Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   School DBN                   212331 non-null  object
#  1   School Name                  212331 non-null  object
#  2   School Level                 212331 non-null  object
#  3   Regents Exam                 212321 non-null  object
#  4   Year                         212331 non-null  int64
#  5   Total Tested                 212331 non-null  int64
#  6   Mean Score                   212331 non-null  object
#  7   Number Scoring Below 65      212331 non-null  object
#  8   Percent Scoring Below 65     212331 non-null  object
#  9   Number Scoring 65 or Above   212331 non-null  object
#  10  Percent Scoring 65 or Above  212331 non-null  object
#  11  Number Scoring 80 or Above   212331 non-null  object
# ...

# %%
df.shape
# Out:
# (212331, 15)

# %%
df.dtypes
# Out:
# School DBN                      object
# School Name                     object
# School Level                    object
# Regents Exam                    object
# Year                             int64
# Total Tested                     int64
# Mean Score                      object
# Number Scoring Below 65         object
# Percent Scoring Below 65        object
# Number Scoring 65 or Above      object
# Percent Scoring 65 or Above     object
# Number Scoring 80 or Above      object
# Percent Scoring 80 or Above     object
# Number Scoring CR              float64
# Percent Scoring CR             float64
# dtype: object

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %% [markdown]
# ###Rename the Columns

# %%
df.rename(columns={
        'School DBN': 'School_DBN','School Level': 'School_Level','Regents Exam':'Regents_Exam','Mean Score':'Mean_Score','Number Scoring Below 65':'Number_Scoring_Below_65','Percent Scoring Below 65':'Percent_Scoring_Below_65',' Number Scoring 65 or Above ':' Number_Scoring_65_or_Above','Percent Scoring 65 or Above':'Percent_Scoring_65_or_Above','Number Scoring 80 or Above':'Number_Scoring_80_or_Above','Percent Scoring 80 or Above':'Percent_Scoring_80_or_Above'}, inplace=True) # to rename the columns

# %%
df
# Out:
#        School_DBN                     School Name School_Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents_Exam  Year  Total Tested Mean_Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %% [markdown]
# ###Let's work with the missing values

# %%
df.isnull()
# Out:
#         School_DBN  School Name  School_Level  Regents_Exam   Year  \
# 0            False        False         False         False  False
# 1            False        False         False         False  False
# 2            False        False         False         False  False
# 3            False        False         False         False  False
# 4            False        False         False         False  False
# ...            ...          ...           ...           ...    ...
# 212326       False        False         False         False  False
# 212327       False        False         False         False  False
# 212328       False        False         False         False  False
# 212329       False        False         False         False  False
# 212330       False        False         False         False  False
#
#         Total Tested  Mean_Score  Number_Scoring_Below_65  \
# 0              False       False                    False
# ...

# %%
df.isnull().sum()
# Out:
# School_DBN                          0
# School Name                         0
# School_Level                        0
# Regents_Exam                       10
# Year                                0
# Total Tested                        0
# Mean_Score                          0
# Number_Scoring_Below_65             0
# Percent_Scoring_Below_65            0
# Number Scoring 65 or Above          0
# Percent_Scoring_65_or_Above         0
# Number_Scoring_80_or_Above          0
# Percent_Scoring_80_or_Above         0
# Number Scoring CR              142680
# Percent Scoring CR             142680
# dtype: int64

# %%
df['Number Scoring CR']=pd.to_numeric(df['Number Scoring CR'],errors='coerce')

# %%
df
# Out:
#        School_DBN                     School Name School_Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents_Exam  Year  Total Tested Mean_Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
df['Percent Scoring CR']=pd.to_numeric(df['Percent Scoring CR'],errors='coerce')

# %%
df
# Out:
#        School_DBN                     School Name School_Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents_Exam  Year  Total Tested Mean_Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %% [markdown]
# ###Imputation of the missing data

# %%
median = df['Number Scoring CR'].median()

# %%
median
# Out:
# 9.0

# %%
median_Percent = df['Percent Scoring CR'].median()

# %%
median_Percent
# Out:
# 29.0

# %% [markdown]
# ###Filling the Dataset

# %%
df['Number Scoring CR'].fillna(median,inplace=True)

# %%
df['Percent Scoring CR'].fillna(median_Percent, inplace=True)

# %%
df
# Out:
#        School_DBN                     School Name School_Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents_Exam  Year  Total Tested Mean_Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %% [markdown]
# ###Basics Informations  of my dataset

# %%
df.groupby('School Name').count()
# Out:
#                                                     School_DBN  School_Level  \
# School Name
# 47 The American Sign Language and English Secondar         356           356
# A. Philip Randolph Campus High School                      459           459
# ACORN Community High School                                364           364
# Abraham Lincoln High School                                480           480
# Abraham Lincoln Yabc                                       248           248
# ...                                                        ...           ...
# Young Women's Leadership School                            378           378
# Young Women's Leadership School of Brooklyn                337           337
# Young Women's Leadership School of the Bronx               142           142
# Young Women's Leadership School, Astoria                   338           338
# Young Women's Leadership School, Queens                    391           391
#
# ...

# %%
df['School Name'].value_counts()
# Out:
# New Visions Charter High School for Advanced Math     1337
# New Visions Charter High School for the Humanities    1031
# Francis Lewis High School                              490
# James Madison High School                              490
# Long Island City High School                           489
#                                                       ...
# Middle School for Academic and Social Excellence         5
# P.S. 202 Ernest S. Jenkyns                               5
# J.H.S. 166 George Gershwin                               5
# Success Academy Charter School - Harlem 3                5
# Explore Excel Charter School                             5
# Name: School Name, Length: 1012, dtype: int64

# %%
df['School_Level'].value_counts()
# Out:
# High school                        151160
# Secondary School                    30252
# Junior High-Intermediate-Middle     15742
# K-12 all grades                      8294
# K-8                                  6858
# Elementary                             25
# Name: School_Level, dtype: int64

# %%
df['School_Level'].value_counts().plot(kind='bar')

# %%
df['Regents_Exam'].value_counts()
# Out:
# Common Core Algebra                29254
# Living Environment                 25539
# U.S. History and Government        20426
# Common Core English                19878
# Global History and Geography       19192
# Physical Settings/Earth Science    15971
# Common Core Geometry               15267
# Physical Settings/Chemistry        11670
# English                            11091
# Integrated Algebra                 11022
# Algebra2/Trigonometry              10788
# Geometry                            8509
# Common Core Algebra2                7915
# Physical Settings/Physics           5799
# Name: Regents_Exam, dtype: int64

# %%
df['Regents_Exam'].value_counts().plot(kind='bar')

# %%
df.groupby(['Year'])['Total Tested'].count()
# Out:
# Year
# 2015    72768
# 2016    76123
# 2017    63440
# Name: Total Tested, dtype: int64

# %%
df.groupby(['Year'])['Total Tested'].count().plot(kind='bar')

# %%
df.groupby('School Name').count()
# Out:
#                                                     School_DBN  School_Level  \
# School Name
# 47 The American Sign Language and English Secondar         356           356
# A. Philip Randolph Campus High School                      459           459
# ACORN Community High School                                364           364
# Abraham Lincoln High School                                480           480
# Abraham Lincoln Yabc                                       248           248
# ...                                                        ...           ...
# Young Women's Leadership School                            378           378
# Young Women's Leadership School of Brooklyn                337           337
# Young Women's Leadership School of the Bronx               142           142
# Young Women's Leadership School, Astoria                   338           338
# Young Women's Leadership School, Queens                    391           391
#
# ...

# %% [markdown]
# ###Picking my School as a initial comparison point

# %%
df_francis_lewisHS = df[df['School Name']== 'Francis Lewis High School']

# %%
df_francis_lewisHS
# Out:
#        School_DBN                School Name School_Level  \
# 14549      26Q430  Francis Lewis High School  High school
# 14550      26Q430  Francis Lewis High School  High school
# 14551      26Q430  Francis Lewis High School  High school
# 14552      26Q430  Francis Lewis High School  High school
# 14553      26Q430  Francis Lewis High School  High school
# ...           ...                        ...          ...
# 194228     26Q430  Francis Lewis High School  High school
# 194229     26Q430  Francis Lewis High School  High school
# 194230     26Q430  Francis Lewis High School  High school
# 194231     26Q430  Francis Lewis High School  High school
# 194232     26Q430  Francis Lewis High School  High school
#
#                        Regents_Exam  Year  Total Tested Mean_Score  \
# 14549         Algebra2/Trigonometry  2015           845       77.8
# 14550         Algebra2/Trigonometry  2016           889       76.7
# ...

# %% [markdown]
# ###Analysis for the selected school

# %%
df_francis_lewisHS['Total Tested'].describe()
# Out:
# count     490.000000
# mean      304.683673
# std       295.056668
# min         1.000000
# 25%        61.250000
# 50%       203.500000
# 75%       490.750000
# max      1264.000000
# Name: Total Tested, dtype: float64

# %%
df_francis_lewisHS['Total Tested'].mean()
# Out:
# 304.68367346938777

# %%
df_francis_lewisHS['Total Tested'].median()
# Out:
# 203.5

# %%
df_francis_lewisHS['Total Tested'].min()
# Out:
# 1

# %%
df_francis_lewisHS['Total Tested'].max()
# Out:
# 1264

# %%
df_francis_lewisHS['Total Tested'].sum()
# Out:
# 149295

# %% [markdown]
# ###Filtering the columns of the selected School

# %%
FL_score_per_year=df_francis_lewisHS[['Year','Total Tested','Number Scoring CR','Percent Scoring CR']]

# %%
FL_best_score_per_year=df_francis_lewisHS[['Year','Total Tested','Number_Scoring_80_or_Above','Percent_Scoring_80_or_Above']]

# %%
FL_best_score_per_year
# Out:
#         Year  Total Tested Number_Scoring_80_or_Above  \
# 14549   2015           845                        461
# 14550   2016           889                        455
# 14551   2017            19                          4
# 14552   2015           541                         58
# 14553   2016           900                        478
# ...      ...           ...                        ...
# 194228  2017           670                        496
# 194229  2017            64                         38
# 194230  2017           225                        115
# 194231  2017             9                          8
# 194232  2017           181                        129
#
#        Percent_Scoring_80_or_Above
# 14549                         54.6
# 14550                         51.2
# 14551                         21.1
# 14552                         10.7
# 14553                         53.1
# ...                            ...
# 194228                          74
# ...

# %%
df_francis_lewisHS_mean=df_francis_lewisHS.groupby(['Year','Total Tested'])['Number Scoring CR','Percent Scoring CR'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df_francis_lewisHS_mean
# Out:
#                    Number Scoring CR  Percent Scoring CR
# Year Total Tested
# 2015 4                      9.000000                29.0
#      6                      2.000000                33.3
#      7                      5.333333                43.0
#      9                      7.000000                42.3
#      10                     9.000000                29.0
# ...                              ...                 ...
# 2017 1106                 923.000000                83.5
#      1118                 848.000000                75.8
#      1149                   9.000000                29.0
#      1235                   9.000000                29.0
#      1258                 988.000000                78.5
#
# [419 rows x 2 columns]

# %% [markdown]
# ### Now let's Compare the selected School with the other School of the dataset

# %%
df['School Name'].value_counts()
# Out:
# New Visions Charter High School for Advanced Math     1337
# New Visions Charter High School for the Humanities    1031
# Francis Lewis High School                              490
# James Madison High School                              490
# Long Island City High School                           489
#                                                       ...
# Middle School for Academic and Social Excellence         5
# P.S. 202 Ernest S. Jenkyns                               5
# J.H.S. 166 George Gershwin                               5
# Success Academy Charter School - Harlem 3                5
# Explore Excel Charter School                             5
# Name: School Name, Length: 1012, dtype: int64

# %% [markdown]
# ###The comparison will be done between my Selected school and James Madison High School

# %% [markdown]
# Selection of all the School "James Madison School"

# %%
df_JamesMadisonHS=df[df['School Name']== 'James Madison High School']

# %%
df_JamesMadisonHS
# Out:
#        School_DBN                School Name School_Level  \
# 12927      22K425  James Madison High School  High school
# 12928      22K425  James Madison High School  High school
# 12929      22K425  James Madison High School  High school
# 12930      22K425  James Madison High School  High school
# 12931      22K425  James Madison High School  High school
# ...           ...                        ...          ...
# 187790     22K425  James Madison High School  High school
# 187791     22K425  James Madison High School  High school
# 187792     22K425  James Madison High School  High school
# 187793     22K425  James Madison High School  High school
# 187794     22K425  James Madison High School  High school
#
#                        Regents_Exam  Year  Total Tested Mean_Score  \
# 12927         Algebra2/Trigonometry  2015           434       67.3
# 12928         Algebra2/Trigonometry  2016           408       70.1
# ...

# %%
JM_score_per_year=df_JamesMadisonHS[['Year','Total Tested','Number Scoring CR','Percent Scoring CR']]

# %%
JM_score_per_year
# Out:
#         Year  Total Tested  Number Scoring CR  Percent Scoring CR
# 12927   2015           434              118.0                27.2
# 12928   2016           408              137.0                33.6
# 12929   2017            28                1.0                 3.6
# 12930   2015           713              174.0                24.4
# 12931   2016           888              515.0                58.0
# ...      ...           ...                ...                 ...
# 187790  2017           160                9.0                29.0
# 187791  2017           116                9.0                29.0
# 187792  2017           136                9.0                29.0
# 187793  2017             9                9.0                29.0
# 187794  2017           383                9.0                29.0
#
# [490 rows x 4 columns]

# %%
JM=df_JamesMadisonHS[['School Name','Year','Total Tested','Number Scoring CR','Percent Scoring CR']]

# %%
FL=df_francis_lewisHS[['School Name','Year','Total Tested','Number Scoring CR','Percent Scoring CR']]

# %%
FL
# Out:
# School Name                Year  Total Tested  Number Scoring CR  Percent Scoring CR
# Francis Lewis High School  2015  4             9.0                29.0                  4
#                            2016  3             9.0                29.0                  4
#                                  5             9.0                29.0                  3
#                                  2             9.0                29.0                  3
#                            2017  5             9.0                29.0                  3
#                                                                                        ..
#                            2015  944           593.0              62.8                  1
#                                  845           461.0              54.6                  1
#                                  840           9.0                29.0                  1
# ...

# %%
JM
# Out:
# School Name                Year  Total Tested  Number Scoring CR  Percent Scoring CR
# James Madison High School  2016  2             9.0                29.0                  6
#                            2015  3             9.0                29.0                  5
#                            2017  2             9.0                29.0                  5
#                                  3             9.0                29.0                  4
#                            2015  104           9.0                29.0                  3
#                                                                                        ..
#                                  1367          9.0                29.0                  1
#                                  1197          9.0                29.0                  1
#                                  920           9.0                29.0                  1
# ...

# %%
merge= pd.merge(FL_score_per_year, JM_score_per_year, on='Year')

# %%
merge
# Out:
#        Year  Total Tested_x  Number Scoring CR_x  Percent Scoring CR_x  \
# 0      2015             845                461.0                  54.6
# 1      2015             845                461.0                  54.6
# 2      2015             845                461.0                  54.6
# 3      2015             845                461.0                  54.6
# 4      2015             845                461.0                  54.6
# ...     ...             ...                  ...                   ...
# 80820  2017             181                  9.0                  29.0
# 80821  2017             181                  9.0                  29.0
# 80822  2017             181                  9.0                  29.0
# 80823  2017             181                  9.0                  29.0
# 80824  2017             181                  9.0                  29.0
#
#        Total Tested_y  Number Scoring CR_y  Percent Scoring CR_y
# ...

# %%
merge1= pd.merge(FL, JM, on='Year')

# %%
merge1
# Out:
#                    School Name_x  Year  Total Tested_x  Number Scoring CR_x  \
# 0      Francis Lewis High School  2015             845                461.0
# 1      Francis Lewis High School  2015             845                461.0
# 2      Francis Lewis High School  2015             845                461.0
# 3      Francis Lewis High School  2015             845                461.0
# 4      Francis Lewis High School  2015             845                461.0
# ...                          ...   ...             ...                  ...
# 80820  Francis Lewis High School  2017             181                  9.0
# 80821  Francis Lewis High School  2017             181                  9.0
# 80822  Francis Lewis High School  2017             181                  9.0
# 80823  Francis Lewis High School  2017             181                  9.0
# 80824  Francis Lewis High School  2017             181                  9.0
#
# ...

# %%
FL_JM= merge1.groupby(['School Name_x','School Name_y']).mean()

# %%
FL_JM
# Out:
#                                                             Year  \
# School Name_x             School Name_y
# Francis Lewis High School James Madison High School  2015.898534
#
#                                                      Total Tested_x  \
# School Name_x             School Name_y
# Francis Lewis High School James Madison High School      302.598763
#
#                                                      Number Scoring CR_x  \
# School Name_x             School Name_y
# Francis Lewis High School James Madison High School           105.301417
#
#                                                      Percent Scoring CR_x  \
# School Name_x             School Name_y
# Francis Lewis High School James Madison High School             41.732218
#
#                                                      Total Tested_y  \
# School Name_x             School Name_y
# Francis Lewis High School James Madison High School      217.796598
#
# ...

# %%
FL_JM[['Percent Scoring CR_x','Percent Scoring CR_y']].plot(kind='bar')

# %%
JM_Bestscore_JM=df_JamesMadisonHS[['Year','Total Tested','Number_Scoring_80_or_Above','Percent_Scoring_80_or_Above']]

# %%
JM_Bestscore_JM
# Out:
#         Year  Total Tested Number_Scoring_80_or_Above  \
# 12927   2015           434                        118
# 12928   2016           408                        137
# 12929   2017            28                          1
# 12930   2015           713                         11
# 12931   2016           888                        194
# ...      ...           ...                        ...
# 187790  2017           160                         98
# 187791  2017           116                         56
# 187792  2017           136                         69
# 187793  2017             9                          5
# 187794  2017           383                        232
#
#        Percent_Scoring_80_or_Above
# 12927                         27.2
# 12928                         33.6
# 12929                          3.6
# 12930                          1.5
# 12931                         21.8
# ...                            ...
# 187790                        61.3
# ...

# %%
JM2=df_JamesMadisonHS[['School Name','Year','Total Tested','Number_Scoring_80_or_Above','Percent_Scoring_80_or_Above']]

# %%
JM2
# Out:
#                       School Name  Year  Total Tested  \
# 12927   James Madison High School  2015           434
# 12928   James Madison High School  2016           408
# 12929   James Madison High School  2017            28
# 12930   James Madison High School  2015           713
# 12931   James Madison High School  2016           888
# ...                           ...   ...           ...
# 187790  James Madison High School  2017           160
# 187791  James Madison High School  2017           116
# 187792  James Madison High School  2017           136
# 187793  James Madison High School  2017             9
# 187794  James Madison High School  2017           383
#
#        Number_Scoring_80_or_Above Percent_Scoring_80_or_Above
# 12927                         118                        27.2
# 12928                         137                        33.6
# 12929                           1                         3.6
# 12930                          11                         1.5
# ...

# %%
FL2=df_francis_lewisHS[['School Name','Year','Total Tested','Number_Scoring_80_or_Above','Percent_Scoring_80_or_Above']]

# %%
FL2
# Out:
#                       School Name  Year  Total Tested  \
# 14549   Francis Lewis High School  2015           845
# 14550   Francis Lewis High School  2016           889
# 14551   Francis Lewis High School  2017            19
# 14552   Francis Lewis High School  2015           541
# 14553   Francis Lewis High School  2016           900
# ...                           ...   ...           ...
# 194228  Francis Lewis High School  2017           670
# 194229  Francis Lewis High School  2017            64
# 194230  Francis Lewis High School  2017           225
# 194231  Francis Lewis High School  2017             9
# 194232  Francis Lewis High School  2017           181
#
#        Number_Scoring_80_or_Above Percent_Scoring_80_or_Above
# 14549                         461                        54.6
# 14550                         455                        51.2
# 14551                           4                        21.1
# 14552                          58                        10.7
# ...

# %%
merge_Bestscore= pd.merge(FL2, JM2, on='Year')

# %%
merge_Bestscore
# Out:
#                    School Name_x  Year  Total Tested_x  \
# 0      Francis Lewis High School  2015             845
# 1      Francis Lewis High School  2015             845
# 2      Francis Lewis High School  2015             845
# 3      Francis Lewis High School  2015             845
# 4      Francis Lewis High School  2015             845
# ...                          ...   ...             ...
# 80820  Francis Lewis High School  2017             181
# 80821  Francis Lewis High School  2017             181
# 80822  Francis Lewis High School  2017             181
# 80823  Francis Lewis High School  2017             181
# 80824  Francis Lewis High School  2017             181
#
#       Number_Scoring_80_or_Above_x Percent_Scoring_80_or_Above_x  \
# 0                              461                          54.6
# 1                              461                          54.6
# 2                              461                          54.6
# ...
